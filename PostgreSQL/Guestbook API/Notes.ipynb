# %%
# pip install passlib and bcrypt for hashing

# %%
from passlib.context import CryptContext

# %%
pwd_context = CryptContext(schemes=['bcrypt'])

# %%
plaintext = "hello"

# %%
pwd_context.hash(plaintext)
